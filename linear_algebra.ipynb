# %%
from matplotlib import pyplot as plt
import numpy as np
from qiskit import *
from qiskit.visualization import plot_bloch_vector

# %%
plot_bloch_vector(1,0,0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e1febe2460e7> in <module>
# ----> 1 plot_bloch_vector(1,0,0)
#
# /usr/local/lib/python3.7/site-packages/qiskit/visualization/state_visualization.py in plot_bloch_vector(bloch, title, ax, figsize)
#     183         figsize = (5, 5)
#     184     B = Bloch(axes=ax)
# --> 185     B.add_vectors(bloch)
#     186     B.render(title=title)
#     187     if ax is None:
#
# /usr/local/lib/python3.7/site-packages/qiskit/visualization/bloch.py in add_vectors(self, vectors)
#     345                 Array with vectors of unit length or smaller.
#     346         """
# --> 347         if isinstance(vectors[0], (list, np.ndarray)):
#     348             for vec in vectors:
#     349                 self.vectors.append(vec)
#
# TypeError: 'int' object is not subscriptable

# %%
plot_bloch_vector([1,1,1])

# %%
plot_bloch_vector([1,1,0])

# %%
plot_bloch_vector([1,0,0])

# %%
plot_bloch_vector([0,0,1])

# %%
plot_bloch_vector([0,1,0])
